# %%
from astropy import units as u   #Conversion y desarrollo de operaciones aritméticas de instancias Quantity
from astropy.table import Table
import numpy as np
from matplotlib import pyplot as plt
import math as mt
#import sys
import pyneb as pn
rc = pn.RedCorr()
rc.law = 'G03 LMC'

# %%
resultList = Table.read("resultList.tbl", format = 'ascii')
OIII5007_WT = 5008.24
Hb_WT = 4862.683
NII6583_WT = 6585.28
Ha_WT = 6564.61
SII6717_WT = 6718.29
SII6731_WT = 6732.67
OIII4959_WT = 4960.295
OII3727_WT = 3727.092
OII3729_WT = 3729.875
OI6300_WT = 6302.046

# %matplotlib

#fig = plt.figure()
#ax = fig.add_subplot(2,1,1)
#ax.set_yscale('log')


#plt.yscale('lin')
#plt.xscale('lin')

cooo = -1
Sy1 = []
Sy2 = []
Stb = []
HIIR = []
LINER=[]
OSy1 = []
OSy2 = []
OStb = []
OHIIR = []
OLINER=[]
SF=[]
lowSF = []
comp=[]
AGN=[]
lowLINER=[]
unclass=[]
OSF=[]
OlowSF = []
Ocomp=[]
OAGN=[]
OlowLINER=[]
Ounclass=[]


#typeBPT = 0  #  NII 
# 1  #  SII OIII5007
# 2 O III5007+4959 and SII
#  3 OII 3727+3729
#  4 OI 6300
# 5 O III/OII vs. OI/Halpha
typeBPT = 5

#typeData = 1   # for sdss query
typeData = 1

limDis = 1.5

plt.title('BPT diagram '+str(typeBPT))

if typeBPT == 0:
    plt.ylabel(r'Log([O III]/ H$\beta$)')
    plt.xlabel(r'Log([N II]/H$\alpha$)')
elif typeBPT == 1:
    plt.ylabel(r'Log([O III]/ H$\beta$)')
    plt.xlabel(r'Log([S II]/H$\alpha$)')
elif typeBPT == 2:
    plt.ylabel(r'Log([O III]+/ H$\beta$)')
    plt.xlabel(r'Log([S II]/H$\alpha$)')
elif typeBPT == 3:
    plt.ylabel(r'Log([O III]/ H$\beta$)')
    plt.xlabel(r'Log([O II]/H$\beta$)')
elif typeBPT == 4:
    plt.ylabel(r'Log([O III]/ H$\beta$)')
    plt.xlabel(r'Log([O I]/H$\alpha$)')
elif typeBPT == 5:
    plt.ylabel(r'Log([O III]/[O II])')
    plt.xlabel(r'Log([O I]/H$\alpha$)')

for iinn in range(len(resultList)):  #  objID in resultList:
    nameTable = "Tabla"+str(resultList['ObjID'][iinn])+".tbl"
    tableObjID = Table.read('resultTables/'+nameTable, format = 'ascii')
    #print str(resultList['ObjID'][iinn]) #  resultList['z'][iinn]
    OII3727 = tableObjID["Flux"][0]
    OII3729 = tableObjID["Flux"][1]
    OIII5007 = tableObjID["Flux"][7]
    OIII4959 = tableObjID["Flux"][6]
    Hb = tableObjID["Flux"][4]
    NII6583 = tableObjID["Flux"][12]
    Ha = tableObjID["Flux"][11] 
    SII6717 = tableObjID["Flux"][13]
    SII6731 = tableObjID["Flux"][14]
    OI6300 = tableObjID["Flux"][15]
    i = 2.8
    rc.setCorr((Ha/Hb)/i, Ha, Hb)
    
    #OII3727 = tableObjID["Amplitude"][0]
    #OII3729 = tableObjID["Amplitude"][1]
    #OIII5007 = tableObjID["Amplitude"][7]
    #OIII4959 = tableObjID["Amplitude"][6]
    #Hb = tableObjID["Amplitude"][4]
    #NII6583 = tableObjID["Amplitude"][12]
    #Ha = tableObjID["Amplitude"][11] 
    #SII6717 = tableObjID["Amplitude"][13]
    #SII6731 = tableObjID["Amplitude"][14]
    #OI6300 = tableObjID["Amplitude"][15]
    # +++++++++++++++
    OII3727_W = tableObjID["Wavelength"][0]
    OII3729_W = tableObjID["Wavelength"][1]
    OIII5007_W = tableObjID["Wavelength"][7]
    OIII4959_W = tableObjID["Wavelength"][6]
    Hb_W = tableObjID["Wavelength"][4]
    NII6583_W = tableObjID["Wavelength"][12]
    Ha_W = tableObjID["Wavelength"][11]
    SII6717_W = tableObjID["Wavelength"][13]
    SII6731_W = tableObjID["Wavelength"][14]
    OI6300_W = tableObjID["Wavelength"][15]

    if typeBPT == 0:   # N II
        if OIII5007>0.0 and Hb>0.0 and NII6583>0.0 and Ha>0.0 and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(Hb_WT-Hb_W)<limDis and mt.fabs(NII6583_WT-NII6583_W)<limDis and mt.fabs(Ha_WT-Ha_W)<limDis:
            cooo = cooo + 1
            #NII6583=NII6583*rc.getCorrHb(NII6583)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            #Hb=Hb*rc.getCorrHb(Hb)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append(NII6583/Ha)
                    OSy1.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append(NII6583/Ha)
                    OSy2.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append(NII6583/Ha)
                    OStb.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'H II':
                    HIIR.append(NII6583/Ha)
                    OHIIR.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Liner':
                    LINER.append(NII6583/Ha)
                    OLINER.append(OIII5007/Hb)
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append(NII6583/Ha)
                    OSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append(NII6583/Ha)
                    OlowSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'comp':
                    comp.append(NII6583/Ha)
                    Ocomp.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'AGN':
                    AGN.append(NII6583/Ha)
                    OAGN.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append(NII6583/Ha)
                    OlowLINER.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'unclass':
                    unclass.append(NII6583/Ha)
                    Ounclass.append(OIII5007/Hb)
                
    elif typeBPT == 1:   # S II
        if OIII5007>0.0 and Hb>0.0 and SII6717>0.0 and SII6731>0.0 and Ha>0.0 and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(Hb_WT-Hb_W)<limDis and mt.fabs(SII6731_WT-SII6731_W)<limDis and mt.fabs(SII6717_WT-SII6717_W)<limDis and mt.fabs(Ha_WT-Ha_W)<limDis:
    #    #    print NII6583/Ha, OIII5007/Hb, nameTable
            cooo = cooo + 1
            #SII6717=SII6717*rc.getCorrHb(SII6717)
            #SII6731=SII6731*rc.getCorrHb(SII6731)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            #Hb=Hb*rc.getCorrHb(Hb)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append((SII6717+SII6731)/Ha)
                    OSy1.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append((SII6717+SII6731)/Ha)
                    OSy2.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append((SII6717+SII6731)/Ha)
                    OStb.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'H II':
                    HIIR.append((SII6717+SII6731)/Ha)
                    OHIIR.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Liner':
                    LINER.append((SII6717+SII6731)/Ha)
                    OLINER.append(OIII5007/Hb)
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append((SII6717+SII6731)/Ha)
                    OSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append((SII6717+SII6731)/Ha)
                    OlowSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'comp':
                    comp.append((SII6717+SII6731)/Ha)
                    Ocomp.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'AGN':
                    AGN.append((SII6717+SII6731)/Ha)
                    OAGN.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append((SII6717+SII6731)/Ha)
                    OlowLINER.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'unclass':
                    unclass.append((SII6717+SII6731)/Ha)
                    Ounclass.append(OIII5007/Hb)
    elif typeBPT == 2:   # O III 5007+ S II
        if OIII4959>0.0 and OIII5007>0.0 and Hb>0.0 and SII6717>0.0 and SII6731>0.0 and Ha>0.0 and mt.fabs(OIII4959_WT-OIII4959_W)<limDis and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(Hb_WT-Hb_W)<limDis and mt.fabs(SII6731_WT-SII6731_W)<limDis and mt.fabs(SII6717_WT-SII6717_W)<limDis and mt.fabs(Ha_WT-Ha_W)<limDis:
    #    #    print NII6583/Ha, OIII5007/Hb, nameTable
            cooo = cooo + 1
            #SII6717=SII6717*rc.getCorrHb(SII6717)
            #SII6731=SII6731*rc.getCorrHb(SII6731)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            #OIII4959=OIII4959*rc.getCorrHb(OIII4959)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            #Hb=Hb*rc.getCorrHb(Hb)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append((SII6717+SII6731)/Ha)
                    OSy1.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append((SII6717+SII6731)/Ha)
                    OSy2.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append((SII6717+SII6731)/Ha)
                    OStb.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'H II':
                    HIIR.append((SII6717+SII6731)/Ha)
                    OHIIR.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'Liner':
                    LINER.append((SII6717+SII6731)/Ha)
                    OLINER.append((OIII5007+OIII4959)/Hb)
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append((SII6717+SII6731)/Ha)
                    OSF.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append((SII6717+SII6731)/Ha)
                    OlowSF.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'comp':
                    comp.append((SII6717+SII6731)/Ha)
                    Ocomp.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'AGN':
                    AGN.append((SII6717+SII6731)/Ha)
                    OAGN.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append((SII6717+SII6731)/Ha)
                    OlowLINER.append((OIII5007+OIII4959)/Hb)
                if resultList['type'][iinn] == 'unclass':
                    unclass.append((SII6717+SII6731)/Ha)
                    Ounclass.append((OIII5007+OIII4959)/Hb)
    elif typeBPT == 3:   # O II
        if OIII5007>0.0 and Hb>0.0 and OII3727>0.0 and OII3729>0.0 and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(Hb_WT-Hb_W)<limDis and mt.fabs(OII3727_WT-OII3727_W)<limDis and mt.fabs(OII3729_WT-OII3729_W)<limDis:
    #    #    print NII6583/Ha, OIII5007/Hb, nameTable
            cooo = cooo + 1
            #OII3727=OII3727*rc.getCorrHb(OII3727)
            #OII3729=OII3729*rc.getCorrHb(OII3729)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            #Hb=Hb*rc.getCorrHb(Hb)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append((OII3727+OII3729)/Hb)
                    OSy1.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append((OII3727+OII3729)/Hb)
                    OSy2.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append((OII3727+OII3729)/Hb)
                    OStb.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'H II':
                    HIIR.append((OII3727+OII3729)/Hb)
                    OHIIR.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Liner':
                    LINER.append((OII3727+OII3729)/Hb)
                    OLINER.append(OIII5007/Hb)
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append((OII3727+OII3729)/Hb)
                    OSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append((OII3727+OII3729)/Hb)
                    OlowSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'comp':
                    comp.append((OII3727+OII3729)/Hb)
                    Ocomp.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'AGN':
                    AGN.append((OII3727+OII3729)/Hb)
                    OAGN.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append((OII3727+OII3729)/Hb)
                    OlowLINER.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'unclass':
                    unclass.append((OII3727+OII3729)/Hb)
                    Ounclass.append(OIII5007/Hb)
    elif typeBPT == 4:  # O I
        if OIII5007>0.0 and Hb>0.0 and OI6300>0.0 and Ha>0.0 and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(Hb_WT-Hb_W)<limDis and mt.fabs(OI6300_WT-OI6300_W)<limDis and mt.fabs(Ha_WT-Ha_W)<limDis:
            cooo = cooo + 1
            #OI6300=OI6300*rc.getCorrHb(OI6300)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            #Hb=Hb*rc.getCorrHb(Hb)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append(OI6300/Ha)
                    OSy1.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append(OI6300/Ha)
                    OSy2.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append(OI6300/Ha)
                    OStb.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'H II':
                    HIIR.append(OI6300/Ha)
                    OHIIR.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'Liner':
                    LINER.append(OI6300/Ha)
                    OLINER.append(OIII5007/Hb)
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append(OI6300/Ha)
                    OSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append(OI6300/Ha)
                    OlowSF.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'comp':
                    comp.append(OI6300/Ha)
                    Ocomp.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'AGN':
                    AGN.append(OI6300/Ha)
                    OAGN.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append(OI6300/Ha)
                    OlowLINER.append(OIII5007/Hb)
                if resultList['type'][iinn] == 'unclass':
                    unclass.append(OI6300/Ha)
                    Ounclass.append(OIII5007/Hb)
    elif typeBPT == 5:  # O III/OII vs. OI/Halpha
        if OIII5007>0.0 and OI6300>0.0 and OII3727>0.0 and OII3729>0.0 and mt.fabs(OII3727_WT-OII3727_W)<limDis and mt.fabs(OII3729_WT-OII3729_W)<limDis and Ha>0.0 and mt.fabs(OIII5007_WT-OIII5007_W)<limDis and mt.fabs(OI6300_WT-OI6300_W)<limDis and mt.fabs(Ha_WT-Ha_W)<limDis:
            cooo = cooo + 1
            #OII3727=OII3727*rc.getCorrHb(OII3727)
            #OII3729=OII3729*rc.getCorrHb(OII3729)
            #OI6300=OI6300*rc.getCorrHb(OI6300)
            #OIII5007=OIII5007*rc.getCorrHb(OIII5007)
            
            #Ha=Ha*rc.getCorrHb(Ha)
            if typeData == 0:
                if resultList['type'][iinn] == 'NL SY1':
                    Sy1.append(OI6300/Ha)
                    OSy1.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'SY2':
                    Sy2.append(OI6300/Ha)
                    OSy2.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'Starburst':
                    Stb.append(OI6300/Ha)
                    OStb.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'H II':
                    HIIR.append(OI6300/Ha)
                    OHIIR.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'Liner':
                    LINER.append(OI6300/Ha)
                    OLINER.append(OIII5007/(OII3727+OII3729))
            else:
                if resultList['type'][iinn] == 'SF':
                    SF.append(OI6300/Ha)
                    OSF.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'lowS/N SF':
                    lowSF.append(OI6300/Ha)
                    OlowSF.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'comp':
                    comp.append(OI6300/Ha)
                    Ocomp.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'AGN':
                    AGN.append(OI6300/Ha)
                    OAGN.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'lowS/N LINER':
                    lowLINER.append(OI6300/Ha)
                    OlowLINER.append(OIII5007/(OII3727+OII3729))
                if resultList['type'][iinn] == 'unclass':
                    unclass.append(OI6300/Ha)
                    Ounclass.append(OIII5007/(OII3727+OII3729))

                
                
if typeData == 0:
    s1 = plt.scatter(np.log10(Sy1), np.log10(OSy1), c='k', marker='o',label='NL SY1')
    s2 = plt.scatter(np.log10(Sy2), np.log10(OSy2), c='yellow', marker='D',label='SY2')
    st = plt.scatter(np.log10(Stb), np.log10(OStb), c='cyan', marker='v',label='Starburst')
    hii = plt.scatter(np.log10(HIIR), np.log10(OHIIR), c='blue', marker='s',label='H II')
    liner = plt.scatter(np.log10(LINER), np.log10(OLINER), c='w', marker='o',label='LINER')
else:
    uncl = plt.scatter(np.log10(unclass), np.log10(Ounclass), c='w', marker='*',label='LINER')
    s1 = plt.scatter(np.log10(SF), np.log10(OSF), c='k', marker='o',label='NL SY1')
    s2 = plt.scatter(np.log10(lowSF), np.log10(OlowSF), c='yellow', marker='D',label='SY2')
    st = plt.scatter(np.log10(comp), np.log10(Ocomp), c='cyan', marker='v',label='Starburst')
    hii = plt.scatter(np.log10(AGN), np.log10(OAGN), c='blue', marker='s',label='H II')
    liner = plt.scatter(np.log10(lowLINER), np.log10(OlowLINER), c='w', marker='o',label='LINER')
    
x = np.log10(np.linspace(0.01, 1, 20))
if typeBPT == 0:
    y = 0.61/(x-0.05) + 1.30
    y1 = 0.61/(x-0.47) + 1.19
    plt.plot(x, y, c='r', label='SF galaxies')
    plt.plot(x, y1, c='dimgrey', ls='--', label='Composite galaxies')
    plt.text(-0.584, 1.72, 'AGN')
    plt.text(-1.12, -0.358, 'H II')
    plt.text(-0.2306, -0.55, 'Comp')
elif (typeBPT == 1) or (typeBPT == 2):
    y = 0.72/(x-0.32) + 1.30
    x1 = np.log10(np.linspace(0.489778, 1, 20))
    y1 = 1.89*x1+0.76
    plt.plot(x, y, c='r', label='SF galaxies')
    plt.plot(x1, y1, c='g', label='aa')
    plt.axvline(x=-0.4,c='dimgrey',lw=1.2,ls='--')
    x1 = np.linspace(-0.57, 0.5, 20)
    plt.plot(x1, [0.5]*len(x1), c='dimgrey',lw=1.2,ls='--')
    plt.text(0.0557, -0.106, 'LINER')
    plt.text(-1.125, 1.467, 'Seyfert')
    plt.text(-1.125, -0.734, 'H II')
elif typeBPT == 3:
    x = np.log10(np.linspace(0.01, 8, 20))
    y = 0.11/(x-0.92) + 0.85
    plt.plot(x, y, c='r', label='SF galaxies')
    plt.text(-0.872, -0.494, 'Star Forming')
    plt.text(-0.872, 1.1987, 'Seyfert 2')
elif typeBPT == 4:
    x = np.log10(np.linspace(0.00316, 0.138038, 20))
    y = 0.73/(x+0.59) + 1.33
    x1 = np.log10(np.linspace(0.074131, 0.4265795, 20))
    y1 = 1.18*x1 + 1.30
    plt.plot(x, y, c='r', label='Theoretical')
    plt.plot(x1, y1, c='dimgrey', label='Theoretical1',lw=1.2,ls='--')
    plt.axvline(x=-0.59,c='g',lw=1.2,ls='--')
    #plt.text(-0.872, -0.494, 'Star Forming')
    #plt.text(-0.872, 1.1987, 'Seyfert 2')
elif typeBPT == 5:
    x = np.log10(np.linspace(0.00316, 0.188018, 20))
    y = -1.701*x - 2.163
    x1 = np.log10(np.linspace(0.08565446, 0.4265795, 20))
    y1 = 1.0*x1 + 0.7
    plt.plot(x, y, c='r', label='Theoretical')
    plt.plot(x1, y1, c='dimgrey', label='Theoretical1',lw=1.2,ls='--')
    #plt.text(-0.872, -0.494, 'Star Forming')
    #plt.text(-0.872, 1.1987, 'Seyfert 2')

if typeData == 0:
    plt.legend((s1, s2, st, hii, liner), ('NL SY1', 'SY2', 'Starburst', 'H II', 'LINER'),ncol=1, markerscale= 2, loc='upper right', fontsize=10)
    print "Sample = ", str(len(resultList))
    print "Number of data selected = ", cooo
    print "NL SY1: ",str(len(Sy1))
    print "SY2: ",str(len(Sy2))
    print "Stb: ",str(len(Stb))
    print "H II: ",str(len(HIIR))
    print "LINER: ",str(len(LINER))
elif typeData == 1:
    plt.legend((s1, s2, st, hii, liner, uncl), ('SF', 'lowSF', 'comp', 'AGN', 'lowLINER', 'uncl'),ncol=1, markerscale= 2, loc='upper right', fontsize=10)
    print "Sample = ", str(len(resultList))
    print "Number of data selected = ", cooo
    print "SF: ",str(len(SF))
    print "lowSF: ",str(len(lowSF))
    print "comp: ",str(len(comp))
    print "AGN: ",str(len(AGN))
    print "lowLINER: ",str(len(lowLINER))
    print "unclass: ",str(len(unclass))
# Out:
# Using matplotlib backend: Qt4Agg
# Sample =  1347
# Number of data selected =  532
# SF:  93
# lowSF:  122
# comp:  37
# AGN:  14
# lowLINER:  55
# unclass:  212
# /usr/lib/python2.7/site-packages/IPython/kernel/__main__.py:98: RuntimeWarning: divide by zero encountered in double_scalars
# /usr/lib/python2.7/site-packages/IPython/kernel/__main__.py:98: RuntimeWarning: invalid value encountered in double_scalars

# %%
#   

tableObjID
# Out:
# <Table masked=False length=16>
#    Amplitude      Wavelength      Sigma      ...    eqWidth     S/N>3
#     float64        float64       float64     ...    float64    string40
# --------------- ------------- -------------- ... ------------- --------
#   11.9943763401 3727.24234337  1.22424513891 ... 33.0601139219     True
#   15.5274448822 3729.90978291 0.954024561582 ... 33.0601139219     True
#   5.79707358491 4341.83440733 0.992545120411 ... 9.81488583179     True
#             0.0      4364.436            0.0 ...           0.0    False
#   11.8564035313 4862.63552297  1.49094543595 ... 16.9821632293     True
# 0.0838832410618 4935.04381529  2.99353030052 ... 3.57573801966    False
#   3.55650215291 4960.40533077  1.80650237803 ...  13.949970541    False
#   11.0778986262 5007.88336579  2.16734586184 ... 27.0178508759     True
#   1.93414709046 5743.43083832 0.490406933187 ... 5.54937410355    False
#             0.0       6529.04            0.0 ...           0.0    False
# ...

# %%
x1 = np.log10(np.linspace(0.489778, 1, 20))
x1
# Out:
# array([-0.31000073, -0.28681887, -0.26481198, -0.24386665, -0.22388518,
#        -0.20478274, -0.18648524, -0.16892757, -0.15205224, -0.13580817,
#        -0.12014984, -0.10503648, -0.09043142, -0.07630158, -0.062617  ,
#        -0.04935049, -0.03647725, -0.02397464, -0.0118219 ,  0.        ])

# %%
ListaLineas=Table.read('LinesAll.txt', format='ascii')
ListaLineas
# Out:
# <Table masked=False length=16>
# LAMBDA VAC ANG SPECTRUM    TT      TERM     J J      LEVEL ENERGY  CM 1
#    float64     string56 string16 string56 string56       string176
# -------------- -------- -------- -------- -------- ----------------------
#       3727.092   [O II]       E2  4So-2Do  3/2-3/2     0.00 -    26830.57
#       3729.875   [O II]       E2  4So-2Do  3/2-5/2     0.00 -    26810.55
#       4341.684      H I       E1      2-5      *-* 82259.11 -   105291.66
#       4364.436  [O III]       E2    1D-1S      2-0 20273.27 -    43185.74
#       4862.683      H I       E1      2-4      *-* 82259.11 -   102823.90
#       4932.603  [O III]       E2    3P-1D      0-2     0.00 -    20273.27
#       4960.295  [O III]       M1    3P-1D      1-2   113.18 -    20273.27
#        5008.24  [O III]       M1    3P-1D      2-2   306.17 -    20273.27
#        5756.24   [N II]       E2    1D-1S      2-0 15316.19 -    32688.64
# ...

# %%
aaaaa = ListaLineas['LAMBDA VAC ANG']
3727.092 in aaaaa
# Out:
# True

# %%
#IntrinsicHB=np.linspace(2.8,3.1,31)
i = 2.8
rc.setCorr((Tablas[jj]['Flux'][11]/Tablas[jj]['Flux'][4])/i, Tablas[jj]['Lambda Vac'][11], Tablas[jj]['Lambda Vac'][4])
Tablas[jj]['Flux'][3-k]*rc.getCorrHb(Tablas[jj]['Lambda Vac'][3-k])
